# %%
import pandas as pd

# %%
# 2 main data types
series=pd.Series(["BMW","Toyota","Honda"])
series1=pd.Series([1,2,3,4,5])

# %%
print(series)
series1
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# series is one dimensional

# %%
colours=pd.Series(["Red","Blue","Black"])

# %%
colours
# Out:
# 0      Red
# 1     Blue
# 2    Black
# dtype: object

# %%
# Data Frame is 2 dimensional

# %%
bike_data=pd.DataFrame({"bikemake":series,"Colour":colours})
car_data=pd.DataFrame({"Carmake":series, "Colour":colours})

# %%
#import Data 
print(bike_data)
car_sale=pd.read_csv("car-sales.csv")
# Out:
#   bikemake Colour
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  Black

# %%
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
 #Exporting a dataframe 
car_sale.to_csv("exported-car-sales.csv", index=False)

# %%
car_sales=pd.read_csv("exported-car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe Data

# %%
car_sale.describe
# Out:
# <bound method NDFrame.describe of      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00>

# %%
# Attribute
car_sale.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
# it will return the columns of the data Frame
car_columns=car_sales.columns
car_columns[0:3]
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)'], dtype='object')

# %%
car_sales.index # it tells all about index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe() # Describe()work on numeric columns.
# Out:
#        Odometer (KM)      Doors         Price  fuel uesd(L)  Number of Wheels
# count      10.000000  10.000000     10.000000     10.000000              10.0
# mean    78601.400000   4.000000   7645.000000   6347.650400               4.0
# std     61983.471735   0.471405   5379.407753   5285.847743               0.0
# min     11179.000000   3.000000   3500.000000    894.320000               4.0
# 25%     35836.250000   4.000000   4625.000000   3225.262500               4.0
# 50%     57369.000000   4.000000   6625.000000   4834.782000               4.0
# 75%     96384.500000   4.000000   7375.000000   7010.167500               4.0
# max    213095.000000   5.000000  22000.000000  19178.550000               4.0

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors         Price  fuel uesd(L)  Number of Wheels
# count      10.000000  10.000000     10.000000     10.000000              10.0
# mean    78601.400000   4.000000   7645.000000   6347.650400               4.0
# std     61983.471735   0.471405   5379.407753   5285.847743               0.0
# min     11179.000000   3.000000   3500.000000    894.320000               4.0
# 25%     35836.250000   4.000000   4625.000000   3225.262500               4.0
# 50%     57369.000000   4.000000   6625.000000   4834.782000               4.0
# 75%     96384.500000   4.000000   7375.000000   7010.167500               4.0
# max    213095.000000   5.000000  22000.000000  19178.550000               4.0

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
# Make                  10 non-null object
# Colour                10 non-null object
# Odometer (KM)         10 non-null int64
# Doors                 10 non-null int64
# Price                 10 non-null float64
# fuel uesd(L)          10 non-null float64
# Number of Wheels      10 non-null int64
# Passed road safety    10 non-null bool
# dtypes: bool(1), float64(2), int64(3), object(2)
# memory usage: 650.0+ bytes

# %%
car_sales.mean()
# Out:
# Odometer (KM)         78601.4000
# Doors                     4.0000
# Price                  7645.0000
# fuel uesd(L)           6347.6504
# Number of Wheels          4.0000
# Passed road safety        1.0000
# dtype: float64

# %%
car_price=pd.Series([10000,3,200])
car_price.mean()
# Out:
# 3401.0

# %%
car_sales.sum()
# Out:
# Make                  toyotahondatoyotabmwnissantoyotahondahondatoyo...
# Colour                    WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                                    786014
# Doors                                                                40
# Price                                                             76450
# fuel uesd(L)                                                    63476.5
# Number of Wheels                                                     40
# Passed road safety                                                   10
# dtype: object

# %%
car_sale["Doors"].sum()
# Out:
# 40

# %%
car_sale["Doors"].mean()
# Out:
# 4.0

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## Selecting and Viewing Data with Pandas

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  fuel uesd(L)  \
# 0  toyota  White         150043      4   4000.0      10503.01
# 1   honda    Red          87899      4   5000.0       7031.92
# 2  toyota   Blue          32549      3   7000.0       2929.41
# 3     bmw  Black          11179      5  22000.0        894.32
# 4  nissan  White         213095      4   3500.0      19178.55
#
#    Number of Wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# 4                 4                True

# %%
car_sale.head(2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00

# %%
car_sales.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc and .iloc
animals=pd.Series(["cat","dog","bird","panda","snake"],index=[0,2,4,6,2])

# %%
animals
# Out:
# 0      cat
# 2      dog
# 4     bird
# 6    panda
# 2    snake
# dtype: object

# %%
# .loc refers to index
animals.loc[2]
# Out:
# 2      dog
# 2    snake
# dtype: object

# %%
animals.loc[6]
# Out:
# 'panda'

# %%
car_sales.loc[3]
# Out:
# Make                     bmw
# Colour                 Black
# Odometer (KM)          11179
# Doors                      5
# Price                  22000
# fuel uesd(L)          894.32
# Number of Wheels           4
# Passed road safety      True
# Name: 3, dtype: object

# %%
#.iloc refers to position
animals.iloc[2]
# Out:
# 'bird'

# %%
animals
# Out:
# 0      cat
# 2      dog
# 4     bird
# 6    panda
# 2    snake
# dtype: object

# %%
animals.iloc[3]
# Out:
# 'panda'

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 2     dog
# 4    bird
# dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  fuel uesd(L)  \
# 0  toyota  White         150043      4   4000.0      10503.01
# 1   honda    Red          87899      4   5000.0       7031.92
# 2  toyota   Blue          32549      3   7000.0       2929.41
# 3     bmw  Black          11179      5  22000.0        894.32
#
#    Number of Wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True

# %%
# here vales come less than index 3.
car_sales.iloc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  fuel uesd(L)  \
# 0  toyota  White         150043      4  4000.0      10503.01
# 1   honda    Red          87899      4  5000.0       7031.92
# 2  toyota   Blue          32549      3  7000.0       2929.41
#
#    Number of Wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True

# %%
car_sales["Make"]
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales.Make
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sale["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sale[car_sale["Make"]=="Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sale[car_sale["Odometer (KM)"]>40000]
print(car_sale[car_sale["Odometer (KM)"]<40000])
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# compare two column
pd.crosstab(car_sales["Make"],car_sales["Colour"])
# Out:
# Colour  Black  Blue  Green  Red  White
# Make
# bmw         1     0      0    0      0
# honda       0     2      0    1      0
# nissan      0     0      0    0      2
# toyota      0     1      1    0      2

# %%
#Group By
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors    Price  fuel uesd(L)  Number of Wheels  \
# Make
# bmw      11179.000000   5.00  22000.0    894.320000               4.0
# honda    62778.333333   4.00   6500.0   5138.101333               4.0
# nissan  122347.500000   4.00   6600.0  10695.275000               4.0
# toyota   85451.250000   3.75   5437.5   6444.332500               4.0
#
#         Passed road safety
# Make
# bmw                   True
# honda                 True
# nissan                True
# toyota                True

# %%
car_sale.groupby(car_sale["Colour"]).mean()
# Out:
#         Odometer (KM)     Doors
# Colour
# Black    11179.000000  5.000000
# Blue     44328.333333  3.666667
# Green    99213.000000  4.000000
# Red      87899.000000  4.000000
# White   113684.500000  4.000000

# %%
import matplotlib 
car_sales["Odometer (KM)"].plot()

# %%
car_sales["Odometer (KM)"].hist()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  fuel uesd(L)  \
# 0  toyota  White         150043      4   4000.0     10503.010
# 1   honda    Red          87899      4   5000.0      7031.920
# 2  toyota   Blue          32549      3   7000.0      2929.410
# 3     bmw  Black          11179      5  22000.0       894.320
# 4  nissan  White         213095      4   3500.0     19178.550
# 5  toyota  Green          99213      4   4500.0      6944.910
# 6   honda   Blue          45698      4   7500.0      4112.820
# 7   honda   Blue          54738      4   7000.0      4269.564
# 8  toyota  White          60000      4   6250.0      5400.000
# 9  nissan  White          31600      4   9700.0      2212.000
#
#    Number of Wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# 4                 4                True
# ...

# %%
car_sales["Price"]=(car_sales["Price"]/100)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  fuel uesd(L)  Number of Wheels  \
# 0  toyota  White         150043      4  0.400     10503.010                 4
# 1   honda    Red          87899      4  0.500      7031.920                 4
# 2  toyota   Blue          32549      3  0.700      2929.410                 4
# 3     bmw  Black          11179      5  2.200       894.320                 4
# 4  nissan  White         213095      4  0.350     19178.550                 4
# 5  toyota  Green          99213      4  0.450      6944.910                 4
# 6   honda   Blue          45698      4  0.750      4112.820                 4
# 7   honda   Blue          54738      4  0.700      4269.564                 4
# 8  toyota  White          60000      4  0.625      5400.000                 4
# 9  nissan  White          31600      4  0.970      2212.000                 4
#
#    Passed road safety
# 0                True
# 1                True
# 2                True
# ...

# %%
car_sales["Price"].plot()

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"]=car_sales["Make"].str.upper()
car_sales["Colour"]=car_sales["Colour"].str.upper()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  fuel uesd(L)  Number of Wheels  \
# 0  TOYOTA  WHITE         150043      4  0.400     10503.010                 4
# 1   HONDA    RED          87899      4  0.500      7031.920                 4
# 2  TOYOTA   BLUE          32549      3  0.700      2929.410                 4
# 3     BMW  BLACK          11179      5  2.200       894.320                 4
# 4  NISSAN  WHITE         213095      4  0.350     19178.550                 4
# 5  TOYOTA  GREEN          99213      4  0.450      6944.910                 4
# 6   HONDA   BLUE          45698      4  0.750      4112.820                 4
# 7   HONDA   BLUE          54738      4  0.700      4269.564                 4
# 8  TOYOTA  WHITE          60000      4  0.625      5400.000                 4
# 9  NISSAN  WHITE          31600      4  0.970      2212.000                 4
#
#    Passed road safety
# 0                True
# 1                True
# 2                True
# ...

# %%
car_sales_missing=pd.read_csv("car-sales-extended-missing-data.csv")
car_sales_missing.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0   Honda  White        35431.0    4.0  15323.0
# 1     BMW   Blue       192714.0    5.0  19943.0
# 2   Honda  White        84714.0    4.0  28343.0
# 3  Toyota  White       154365.0    4.0  13434.0
# 4  Nissan   Blue       181577.0    3.0  14043.0

# %%
car_sales_missing["Odometer (KM)"].fillna(car_sales_missing["Odometer (KM)"].mean(),inplace=True)

# %%
car_sales_missing.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0   Honda  White        35431.0    4.0  15323.0
# 1     BMW   Blue       192714.0    5.0  19943.0
# 2   Honda  White        84714.0    4.0  28343.0
# 3  Toyota  White       154365.0    4.0  13434.0
# 4  Nissan   Blue       181577.0    3.0  14043.0

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0   Honda  White        35431.0    4.0  15323.0
# 1     BMW   Blue       192714.0    5.0  19943.0
# 2   Honda  White        84714.0    4.0  28343.0
# 3  Toyota  White       154365.0    4.0  13434.0
# 4  Nissan   Blue       181577.0    3.0  14043.0

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  fuel uesd(L)  Number of Wheels  \
# 0  TOYOTA  WHITE         150043      4  0.400     10503.010                 4
# 1   HONDA    RED          87899      4  0.500      7031.920                 4
# 2  TOYOTA   BLUE          32549      3  0.700      2929.410                 4
# 3     BMW  BLACK          11179      5  2.200       894.320                 4
# 4  NISSAN  WHITE         213095      4  0.350     19178.550                 4
# 5  TOYOTA  GREEN          99213      4  0.450      6944.910                 4
# 6   HONDA   BLUE          45698      4  0.750      4112.820                 4
# 7   HONDA   BLUE          54738      4  0.700      4269.564                 4
# 8  TOYOTA  WHITE          60000      4  0.625      5400.000                 4
# 9  NISSAN  WHITE          31600      4  0.970      2212.000                 4
#
#    Passed road safety
# 0                True
# 1                True
# 2                True
# ...

# %%
# Column for Python List
fuel_economy=[7,8,9,8,9,7,9,7.8,9,7]
car_sales["Fuel per 100km"]=fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Fuel per 100km
# 0  toyota  White         150043      4   4000.0             7.0
# 1   honda    Red          87899      4   5000.0             8.0
# 2  toyota   Blue          32549      3   7000.0             9.0
# 3     bmw  Black          11179      5  22000.0             8.0
# 4  nissan  White         213095      4   3500.0             9.0
# 5  toyota  Green          99213      4   4500.0             7.0
# 6   honda   Blue          45698      4   7500.0             9.0
# 7   honda   Blue          54738      4   7000.0             7.8
# 8  toyota  White          60000      4   6250.0             9.0
# 9  nissan  White          31600      4   9700.0             7.0

# %%
car_sales["fuel uesd(L)"]=car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100km"]

# %%
car_sales["Number of Wheels"]=4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Fuel per 100km  fuel uesd(L)  \
# 0  toyota  White         150043      4   4000.0             7.0     10503.010
# 1   honda    Red          87899      4   5000.0             8.0      7031.920
# 2  toyota   Blue          32549      3   7000.0             9.0      2929.410
# 3     bmw  Black          11179      5  22000.0             8.0       894.320
# 4  nissan  White         213095      4   3500.0             9.0     19178.550
# 5  toyota  Green          99213      4   4500.0             7.0      6944.910
# 6   honda   Blue          45698      4   7500.0             9.0      4112.820
# 7   honda   Blue          54738      4   7000.0             7.8      4269.564
# 8  toyota  White          60000      4   6250.0             9.0      5400.000
# 9  nissan  White          31600      4   9700.0             7.0      2212.000
#
#    Number of Wheels
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# ...

# %%
car_sales["Passed road safety"]=True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Fuel per 100km  fuel uesd(L)  \
# 0  toyota  White         150043      4   4000.0             7.0     10503.010
# 1   honda    Red          87899      4   5000.0             8.0      7031.920
# 2  toyota   Blue          32549      3   7000.0             9.0      2929.410
# 3     bmw  Black          11179      5  22000.0             8.0       894.320
# 4  nissan  White         213095      4   3500.0             9.0     19178.550
# 5  toyota  Green          99213      4   4500.0             7.0      6944.910
# 6   honda   Blue          45698      4   7500.0             9.0      4112.820
# 7   honda   Blue          54738      4   7000.0             7.8      4269.564
# 8  toyota  White          60000      4   6250.0             9.0      5400.000
# 9  nissan  White          31600      4   9700.0             7.0      2212.000
#
#    Number of Wheels  Passed road safety
# 0                 4                True
# ...

# %%
# To Drop a column 
car_sales=car_sales.drop("Fuel per 100km",axis=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  fuel uesd(L)  \
# 0  toyota  White         150043      4   4000.0     10503.010
# 1   honda    Red          87899      4   5000.0      7031.920
# 2  toyota   Blue          32549      3   7000.0      2929.410
# 3     bmw  Black          11179      5  22000.0       894.320
# 4  nissan  White         213095      4   3500.0     19178.550
# 5  toyota  Green          99213      4   4500.0      6944.910
# 6   honda   Blue          45698      4   7500.0      4112.820
# 7   honda   Blue          54738      4   7000.0      4269.564
# 8  toyota  White          60000      4   6250.0      5400.000
# 9  nissan  White          31600      4   9700.0      2212.000
#
#    Number of Wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# 4                 4                True
# ...

# %%
car_sales_shuffled=car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  fuel uesd(L)  \
# 7   honda   Blue          54738      4   7000.0      4269.564
# 3     bmw  Black          11179      5  22000.0       894.320
# 5  toyota  Green          99213      4   4500.0      6944.910
# 9  nissan  White          31600      4   9700.0      2212.000
# 0  toyota  White         150043      4   4000.0     10503.010
# 2  toyota   Blue          32549      3   7000.0      2929.410
# 1   honda    Red          87899      4   5000.0      7031.920
# 4  nissan  White         213095      4   3500.0     19178.550
# 8  toyota  White          60000      4   6250.0      5400.000
# 6   honda   Blue          45698      4   7500.0      4112.820
#
#    Number of Wheels  Passed road safety
# 7                 4                True
# 3                 4                True
# 5                 4                True
# 9                 4                True
# 0                 4                True
# ...

# %%
car_sales_shuffled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  fuel uesd(L)  \
# 2  toyota   Blue          32549      3  7000.0       2929.41
# 9  nissan  White          31600      4  9700.0       2212.00
#
#    Number of Wheels  Passed road safety
# 2                 4                True
# 9                 4                True

# %%
car_sales_shuffled=car_sales_shuffled.reset_index()

# %%
car_sales_shuffled
# Out:
#    index    Make Colour  Odometer (KM)  Doors       Price  Number of Wheels  \
# 0      5  Toyota  Green          99213      4   $4,500.00                 4
# 1      3     BMW  Black          11179      5  $22,000.00                 4
# 2      9  Nissan  White          31600      4   $9,700.00                 4
# 3      8  Toyota  White          60000      4   $6,250.00                 4
# 4      6   Honda   Blue          45698      4   $7,500.00                 4
# 5      2  Toyota   Blue          32549      3   $7,000.00                 4
# 6      4  Nissan  White         213095      4   $3,500.00                 4
# 7      0  Toyota  White         150043      4   $4,000.00                 4
# 8      7   Honda   Blue          54738      4   $7,000.00                 4
# 9      1   Honda    Red          87899      4   $5,000.00                 4
#
#    Passed road safety
# 0                True
# 1                True
# 2                True
# 3                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Number of Wheels  \
# 0  Toyota  White         150043      4   $4,000.00                 4
# 1   Honda    Red          87899      4   $5,000.00                 4
# 2  Toyota   Blue          32549      3   $7,000.00                 4
# 3     BMW  Black          11179      5  $22,000.00                 4
# 4  Nissan  White         213095      4   $3,500.00                 4
# 5  Toyota  Green          99213      4   $4,500.00                 4
# 6   Honda   Blue          45698      4   $7,500.00                 4
# 7   Honda   Blue          54738      4   $7,000.00                 4
# 8  Toyota  White          60000      4   $6,250.00                 4
# 9  Nissan  White          31600      4   $9,700.00                 4
#
#    Passed road safety
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# 5                True
# 6                True
# ...

# %%
car_sales["Odometer (KM)"]= car_sales["Odometer (KM)"].apply(lambda x:x/1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Number of Wheels  \
# 0  Toyota  White      93776.875      4   $4,000.00                 4
# 1   Honda    Red      54936.875      4   $5,000.00                 4
# 2  Toyota   Blue      20343.125      3   $7,000.00                 4
# 3     BMW  Black       6986.875      5  $22,000.00                 4
# 4  Nissan  White     133184.375      4   $3,500.00                 4
# 5  Toyota  Green      62008.125      4   $4,500.00                 4
# 6   Honda   Blue      28561.250      4   $7,500.00                 4
# 7   Honda   Blue      34211.250      4   $7,000.00                 4
# 8  Toyota  White      37500.000      4   $6,250.00                 4
# 9  Nissan  White      19750.000      4   $9,700.00                 4
#
#    Passed road safety
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# 5                True
# 6                True
# ...
